# %% [markdown]
# # importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot  as plt
import seaborn as sns

# %% [markdown]
# # loading and understanding data

# %%
df = pd.read_excel("C:\\Users\\DELL\\Desktop\\Assignments\\Clustering\\EastWestAirlines.xlsx")

# %%
df
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
df.shape
# Out:
# (3999, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
df.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
df.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %% [markdown]
# # Data Visualization

# %%
df.iloc[:, 1:].hist()
# Out:
# array([[<Axes: title={'center': 'Balance'}>,
#         <Axes: title={'center': 'Qual_miles'}>,
#         <Axes: title={'center': 'cc1_miles'}>],
#        [<Axes: title={'center': 'cc2_miles'}>,
#         <Axes: title={'center': 'cc3_miles'}>,
#         <Axes: title={'center': 'Bonus_miles'}>],
#        [<Axes: title={'center': 'Bonus_trans'}>,
#         <Axes: title={'center': 'Flight_miles_12mo'}>,
#         <Axes: title={'center': 'Flight_trans_12'}>],
#        [<Axes: title={'center': 'Days_since_enroll'}>,
#         <Axes: title={'center': 'Award?'}>, <Axes: >]], dtype=object)

# %%
plt.figure(figsize = (20,10))
sns.boxplot(df.iloc[:, 1:])
# Out:
# <Axes: >

# %%
# Compute correlation matrix
correlation_matrix = df.iloc[:, 1:].corr()

# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f", linewidths=1.5)
plt.title("Feature Correlation Heatmap", fontsize=16)
plt.show()

# %%
df1 = df.drop('ID#', axis = 1)

# %%
df1.columns
# Out:
# Index(['Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %% [markdown]
# # Model Building

# %%
X = df1.drop(columns=['Award?'])  # Features
y = df1['Award?']  # Target Variable (0 or 1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# # Agglomerative Clustering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
# Apply Agglomerative Clustering
AC = AgglomerativeClustering(n_clusters=2, metric='euclidean', linkage='ward')  # 2 clusters since target is binary
clusters_ac = AC.fit_predict(X_scaled)

# %%
# Add cluster labels to DataFrame for analysis
df1['Cluster_ac'] = clusters_ac

# %%
df1.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    Cluster_ac
# 0           1
# 1           1
# 2           1
# 3           1
# ...

# %%
from sklearn.metrics import silhouette_score

# %%
sil_score_Hierarchy = silhouette_score(X_scaled, clusters_ac)

# %%
print(f"Silhouette Score(Agglomerative): {sil_score_Hierarchy:.3f}")
# Out:
# Silhouette Score(Agglomerative): 0.325

# %%
from sklearn.metrics import accuracy_score, classification_report

# %%
cr = classification_report(df1['Award?'], df1['Cluster_ac'])

# %%
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.40      0.17      0.24      2518
#            1       0.28      0.55      0.37      1481
#
#     accuracy                           0.31      3999
#    macro avg       0.34      0.36      0.31      3999
# weighted avg       0.35      0.31      0.29      3999

# %% [markdown]
# # KMeans Clustering

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=2, random_state=42, n_init=6)
clusters_kmeans = kmeans.fit_predict(X_scaled)

# %%
cluster_labels = np.where(clusters_kmeans == pd.Series(clusters_kmeans)[y == 1].mode()[0], 1, 0)

# %%
df1['Cluster_km'] = clusters_kmeans

# %%
df1.head()
# Out:
#    Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    28143           0          1          1          1          174
# 1    19244           0          1          1          1          215
# 2    41354           0          1          1          1         4123
# 3    14776           0          1          1          1          500
# 4    97752           0          4          1          1        43300
#
#    Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  Award?  \
# 0            1                  0                0               7000       0
# 1            2                  0                0               6968       0
# 2            4                  0                0               7034       0
# 3            1                  0                0               6952       0
# 4           26               2077                4               6935       1
#
#    Cluster_ac  Cluster_km
# 0           1           0
# 1           1           0
# ...

# %%
sil_score_kmeans = silhouette_score(X_scaled, clusters_kmeans)
print(f"Silhouette Score(kmeans): {sil_score_kmeans:.3f}")
# Out:
# Silhouette Score(kmeans): 0.358

# %%
cr_km = classification_report(df1['Award?'], df1['Cluster_km'])

# %%
print(cr_km)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78      2518
#            1       0.63      0.51      0.56      1481
#
#     accuracy                           0.71      3999
#    macro avg       0.68      0.67      0.67      3999
# weighted avg       0.70      0.71      0.70      3999

# %% [markdown]
# # DBScan Clustering

# %%
from sklearn.cluster import DBSCAN

# %%
cluster_dbscan = DBSCAN(eps=0.8, min_samples=12)
cluster_dbscan.fit(X_scaled)
# Out:
# DBSCAN(eps=0.8, min_samples=12)

# %%
cluster_dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
cluster_Dbs=pd.DataFrame(cluster_dbscan.labels_,columns=['cluster_Dbs'])

# %%
df1['cluster_Dbs'] = cluster_dbscan.labels_

# %%
df1
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
sil_score_dbs = silhouette_score(X_scaled, cluster_Dbs)
print(f"Silhouette Score(dbscan): {sil_score_dbs:.3f}")
# Out:
# C:\Users\DELL\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Silhouette Score(dbscan): 0.416

# %%
from sklearn.decomposition import PCA

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# # Visualization of Clustering

# %%
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=clusters_ac, palette="coolwarm")
plt.title("Agglomerative Clustering")
# Out:
# Text(0.5, 1.0, 'Agglomerative Clustering')

# %%
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=clusters_kmeans, palette="viridis")
plt.title("K-Means Clustering")
# Out:
# Text(0.5, 1.0, 'K-Means Clustering')

# %%
sns.scatterplot(x=X_pca[:, 0], y=X_pca[:, 1], hue=cluster_dbscan, palette="viridis")
plt.title("DBScan Clustering")
# Out:
# Text(0.5, 1.0, 'DBScan Clustering')

# %% [markdown]
# Among three clustering methods Kmeans clustering methods gives most precise and high silhouette score cluster.
# DBScan method is used for large data where noise is considered as -1, here in this dataset we cant cluster -1 point due to its
# binary classification
# silhouette scores Kmeans > DBScan > Agglomerative
