# %% [markdown]
# Importing libraries

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# loading data

# %%
df = pd.read_csv("C:\\Users\\DELL\\Desktop\\Assignments\\EDA1\\Cardiotocographic.csv")

# %%
df
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %% [markdown]
# understanding data

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB
# (2126, 14)

# %% [markdown]
# basic statistical understanding of data

# %%
df.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2105.000000  2106.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.270154     0.004391     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001634     0.000000     0.004484     0.000000
# 75%     140.000000     0.005650     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2105.000000  2105.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000142     0.000840    18.813973     1.173632    21.205041
# ...

# %% [markdown]
# checking for null values

# %%
df.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# #imputing null value with mean

# %%
df1 = df.fillna(df.mean())

# %%
df1.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean    133.343598     0.003219     0.009894     0.004391     0.001895
# std      11.214328     0.004370     0.067540     0.003340     0.003343
# min      51.842487    -0.019284    -0.480634    -0.014925    -0.015393
# 25%     126.000000     0.000000     0.000000     0.001851     0.000000
# 50%     133.000000     0.001668     0.000000     0.004484     0.000000
# 75%     140.000000     0.005606     0.002567     0.006536     0.003289
# max     214.000000     0.038567     0.961268     0.030002     0.030769
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.995984     1.364378    10.285964
# std       0.000141     0.000836    18.813973     1.173632    21.205041
# ...

# %%
df1.isnull().sum()
# Out:
# LB          0
# AC          0
# FM          0
# UC          0
# DL          0
# DS          0
# DP          0
# ASTV        0
# MSTV        0
# ALTV        0
# MLTV        0
# Width       0
# Tendency    0
# NSP         0
# dtype: int64

# %% [markdown]
# #Detecting and imputing outliers

# %%
plt.boxplot(df1['AC'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2e1cf8f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2e1cfec0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2851ffb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2e260500>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2e260800>],
#  'means': []}

# %%
df1['AC'] = df1['AC'].apply(lambda x: df1['AC'].median() if x < -0.000184863 or x > 0.012 else x)

# %%
plt.boxplot(df1['AC'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2e2e9c40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2e2ea240>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2e2e99a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2e2ea6f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2e2eaa20>],
#  'means': []}

# %%
plt.boxplot(df1['LB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2e364ce0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2e365250>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2e3649b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2e3656a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2e365970>],
#  'means': []}

# %%
df1['LB'] = df1['LB'].replace(51.842487, 126)
df1['LB'] = df1['LB'].replace(214.000000, 140)
plt.boxplot(df1['LB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2e3abf20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2e3dc4d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2e3abc50>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2e3dcaa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2e3dccb0>],
#  'means': []}

# %%
df1['UC'] = df1['UC'].apply(lambda x: df1['UC'].median() if x < -0.001 or x > 0.013 else x)
plt.boxplot(df1['UC'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2e431f70>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2e4324e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2e431d00>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2e432ab0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2e432c30>],
#  'means': []}

# %%
df1['FM'] = df1['FM'].apply(lambda x: df1['FM'].median() if x < 0.002567 or x > 0.000 else x)

# %%
plt.boxplot(df1['FM'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2eb753a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2eb75970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2eb750d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2eb75be0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2eb75f40>],
#  'means': []}

# %%
plt.boxplot(df1['DL'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2ec346e0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2ec34c80>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2ec34410>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2ebee810>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2ec34e00>],
#  'means': []}

# %%
df1['DL'].describe()
# Out:
# count    2126.000000
# mean        0.001895
# std         0.003343
# min        -0.015393
# 25%         0.000000
# 50%         0.000000
# 75%         0.003289
# max         0.030769
# Name: DL, dtype: float64

# %%
df1['DL'] = df1['DL'].apply(lambda x: df1['DL'].mean() if x < 0.003289 or x > 0.000000 else x)

# %%
plt.boxplot(df1['DL'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2ec91430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2ec919a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2ec91190>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2ec91e80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2ec92180>],
#  'means': []}

# %%
df1['DS'].describe()
# Out:
# count    2126.000000
# mean        0.000003
# std         0.000141
# min        -0.001353
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         0.002706
# Name: DS, dtype: float64

# %%
plt.boxplot(df1['ASTV'])
df1['ASTV'].describe()
# Out:
# count    2126.000000
# mean       46.995984
# std        18.813973
# min       -63.000000
# 25%        32.000000
# 50%        49.000000
# 75%        61.000000
# max       162.000000
# Name: ASTV, dtype: float64

# %%
df1['ASTV'] = df1['ASTV'].replace(-63,32.00)

# %%
df1['ASTV'] = df1['ASTV'].replace(162.00,61.00)

# %%
plt.boxplot(df1['ASTV'])
df1['ASTV'].describe()
# Out:
# count    2126.000000
# mean       46.981873
# std        17.186262
# min        11.799846
# 25%        32.000000
# 50%        49.000000
# 75%        61.000000
# max        87.000000
# Name: ASTV, dtype: float64

# %%
plt.boxplot(df1['MSTV'])
df1['MSTV'].describe()
# Out:
# count    2126.000000
# mean        1.364378
# std         1.173632
# min        -6.600000
# 25%         0.700000
# 50%         1.200000
# 75%         1.700000
# max        13.800000
# Name: MSTV, dtype: float64

# %%
for x in df1['MSTV']:
    if x > 1.700000 :
        df1['MSTV'] = df1['MSTV'].replace(x,1.700000)
    elif x < 0.700000 :
         df1['MSTV'] = df1['MSTV'].replace(x,0.700000)

# %%
plt.boxplot(df1['MSTV'])
df1['MSTV'].describe()
# Out:
# count    2126.000000
# mean        1.188517
# std         0.411381
# min         0.700000
# 25%         0.700000
# 50%         1.200000
# 75%         1.700000
# max         1.700000
# Name: MSTV, dtype: float64

# %%
df1['ALTV'].describe()
# Out:
# count    2126.000000
# mean       10.285964
# std        21.205041
# min       -91.000000
# 25%         0.000000
# 50%         0.000000
# 75%        11.000000
# max       182.000000
# Name: ALTV, dtype: float64

# %%
plt.boxplot(df1['ALTV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cf39578bf0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cf395d1bb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cf3957be60>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cf395d33b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cf37301790>],
#  'means': []}

# %%
for x in df1['ALTV']:
    if x > 11.000000 :
        df1['ALTV'] = df1['ALTV'].replace(x,11.000000)
    elif x < 0.000000 :
         df1['ALTV'] = df1['ALTV'].replace(x,0.000000)

# %%
plt.boxplot(df1['ALTV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2ed00770>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2ed020c0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2ed01190>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2e3f9970>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2ecf9670>],
#  'means': []}

# %%
df1['MLTV'].describe()
# Out:
# count    2126.000000
# mean        8.284887
# std         7.734356
# min       -50.700000
# 25%         4.600000
# 50%         7.500000
# 75%        10.800000
# max       101.400000
# Name: MLTV, dtype: float64

# %%
plt.boxplot(df1['MLTV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2ff0dee0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2ff0e4e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2ff0dc10>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2ff0e750>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2ff0e930>],
#  'means': []}

# %%
for x in df1['MLTV']:
    if x > 10.800000 :
        df1['MLTV'] = df1['MLTV'].replace(x,10.800000)
    elif x < 4.600000 :
         df1['MLTV'] = df1['MLTV'].replace(x,4.600000)

# %%
plt.boxplot(df1['MLTV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2ffa0f50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2ffa1430>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2ffa0c80>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2ffa1880>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2ffa1b20>],
#  'means': []}

# %%
plt.boxplot(df1['Width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2e367890>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2ecf89e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2ff4f920>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2fef5af0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2fef6660>],
#  'means': []}

# %%
df1['Width'].describe()
# Out:
# count    2126.000000
# mean       70.429260
# std        42.719161
# min      -174.000000
# 25%        37.000000
# 50%        68.000000
# 75%       100.000000
# max       357.000000
# Name: Width, dtype: float64

# %%
df1['Width'] = df1['Width'].replace({357.000000 : 100.000000, -174.000000 : 37.000000 })

# %%
plt.boxplot(df1['Width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2ec93200>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2ec00350>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2ec92840>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2ed03470>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b2ed01bb0>],
#  'means': []}

# %%
plt.boxplot(df1['Tendency'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x14b2ffdf3b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x14b2ffdf9e0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x14b2ed01910>],
#  'medians': [<matplotlib.lines.Line2D at 0x14b2ffdfe60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x14b30048170>],
#  'means': []}

# %%
df1['Tendency'].describe()
# Out:
# count    2126.000000
# mean        0.316371
# std         0.642424
# min        -3.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         3.000000
# Name: Tendency, dtype: float64

# %%
for x in df1['Tendency']:
    if x > 1.000000 :
        df1['Tendency'] = df1['Tendency'].replace(x,1.000000)
    elif x < 0.000000 :
         df1['Tendency'] = df1['Tendency'].replace(x,0.000000)

# %%
plt.boxplot(df1['Tendency'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cf398f0fe0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cf398f1520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cf39afcd40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cf398f19a0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cf398f1c40>],
#  'means': []}

# %%
df1.describe()
# Out:
#                 LB           AC      FM           UC            DL  \
# count  2126.000000  2126.000000  2126.0  2126.000000  2.126000e+03
# mean    133.134755     0.002728     0.0     0.004341  1.895345e-03
# std      10.366980     0.003212     0.0     0.002911  7.070661e-17
# min      51.842487    -0.000185     0.0    -0.000132  1.895345e-03
# 25%     126.000000     0.000000     0.0     0.001880  1.895345e-03
# 50%     133.000000     0.001668     0.0     0.004484  1.895345e-03
# 75%     140.000000     0.004798     0.0     0.006504  1.895345e-03
# max     160.000000     0.011986     0.0     0.012987  1.895345e-03
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2126.000000  2126.000000  2126.000000  2126.000000  2126.000000
# mean      0.000003     0.000175    46.981873     1.188517     3.587363
# std       0.000141     0.000836    17.186262     0.411381     4.795547
# min      -0.001353    -0.005348    11.799846     0.700000     0.000000
# ...

# %% [markdown]
# #histogram vizualization for understanding after imputation of ouliers

# %%
plt.figure(figsize = (50,50))
df1.hist()
# Out:
# array([[<Axes: title={'center': 'LB'}>, <Axes: title={'center': 'AC'}>,
#         <Axes: title={'center': 'FM'}>, <Axes: title={'center': 'UC'}>],
#        [<Axes: title={'center': 'DL'}>, <Axes: title={'center': 'DS'}>,
#         <Axes: title={'center': 'DP'}>, <Axes: title={'center': 'ASTV'}>],
#        [<Axes: title={'center': 'MSTV'}>,
#         <Axes: title={'center': 'ALTV'}>,
#         <Axes: title={'center': 'MLTV'}>,
#         <Axes: title={'center': 'Width'}>],
#        [<Axes: title={'center': 'Tendency'}>,
#         <Axes: title={'center': 'NSP'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %% [markdown]
# #Understanding data correlation with vizualization

# %%
plt.figure(figsize=(50,50))
sns.pairplot(kind = 'scatter', data = df1)

# %%
sns.heatmap(df1.corr())
# Out:
# <Axes: >

# %% [markdown]
# #correlation matrix

# %%
DF2 = df1.corr()

# %%
DF2
# Out:
#                 LB        AC  FM        UC  DL        DS        DP      ASTV  \
# LB        1.000000 -0.103597 NaN -0.138738 NaN -0.005612 -0.047400  0.280227
# AC       -0.103597  1.000000 NaN  0.124614 NaN -0.042381 -0.074101 -0.268372
# FM             NaN       NaN NaN       NaN NaN       NaN       NaN       NaN
# UC       -0.138738  0.124614 NaN  1.000000 NaN -0.007641  0.076129 -0.229026
# DL             NaN       NaN NaN       NaN NaN       NaN       NaN       NaN
# DS       -0.005612 -0.042381 NaN -0.007641 NaN  1.000000  0.004285  0.009321
# DP       -0.047400 -0.074101 NaN  0.076129 NaN  0.004285  1.000000  0.041899
# ASTV      0.280227 -0.268372 NaN -0.229026 NaN  0.009321  0.041899  1.000000
# MSTV     -0.331718  0.246067 NaN  0.295144 NaN  0.037057  0.162360 -0.495514
# ALTV      0.315553 -0.428446 NaN -0.281156 NaN -0.007629 -0.124256  0.414430
# MLTV     -0.086758 -0.081689 NaN -0.045458 NaN  0.011479 -0.156352 -0.327768
# ...

# %% [markdown]
# Q) Summarize the key insights and patterns discovered through your exploratory analysis.

# %% [markdown]
# Key Correlations
# Strong Positive Correlations:
# ASTV and NSP (0.457):
#
# This indicates that as the "Percentage of Time with Abnormal Short-Term Variability" (ASTV) increases, the probability of a specific class in the "NSP" (normal, suspect, or pathological) label also increases. ASTV might be a key predictor of fetal health status.
# MSTV and Width (0.661):
#
# A strong relationship exists between the "Mean Value of Short-Term Variability" (MSTV) and "Width," which may suggest these variables together influence fetal conditions or health trends.
# ALTV and ASTV (0.414):
#
# "Percentage of Time with Abnormal Long-Term Variability" (ALTV) and ASTV are positively correlated. This could mean that variability in short and long-term measures tends to align in abnormal fetal conditions.
# DP and NSP (0.294):
#
# "Decelerations Prolonged" (DP) has a moderately positive correlation with NSP, implying that prolonged decelerations could indicate abnormal fetal conditions.
# Strong Negative Correlations:
# MSTV and ASTV (-0.495):
#
# There's a negative correlation between "Mean Value of Short-Term Variability" (MSTV) and "Percentage of Time with Abnormal Short-Term Variability" (ASTV). This suggests that higher variability in the abnormal range may reduce the mean variability overall.
# ALTV and MSTV (-0.609):
#
# A strong negative correlation indicates that abnormal long-term variability (ALTV) reduces the mean short-term variability (MSTV). These metrics might inversely reflect different aspects of fetal heart health.
# AC and ALTV (-0.428):
#
# Accelerations (AC) are negatively correlated with "Percentage of Time with Abnormal Long-Term Variability" (ALTV). This suggests that fetal movements with higher accelerations may lead to reduced long-term abnormal variability.
# Potential Insights:
# ASTV and ALTV: Both seem critical to determining NSP, as they show significant correlations with this target variable.
# MSTV and Width: Their strong relationship might indicate mechanical or physiological factors influencing fetal variability.
# Prolonged Decelerations (DP): Could be a warning sign for abnormal conditions given its moderate positive correlation with NSP.
# Next Steps:
# Feature Selection for Modeling: Focus on ASTV, ALTV, MSTV, DP, and Width as these are strongly correlated with the target variable NSP or each other.
# Further Investigation: Examine potential multi-collinearity among ASTV, ALTV, and MSTV to avoid redundancy in predictive models.

# %% [markdown]
# Q) Discuss how these findings could impact decision-making or further analyses

# %% [markdown]
# We can use these insights from the data as to build model to predict any involuntury actions with target NSP. Clinicians can also use these indicators
# to monitor fetal health more closely and take early action when abnormal patterns appear. Overall, these insights help in designing smarter health
# systems, better diagnostic tools, and more focused medical protocols.
