# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # LOADING DATA

# %%
df = pd.read_csv("C:\\Users\\DELL\\Desktop\\Assignments\\MLR\\ToyotaCorolla - MLR.csv")

# %% [markdown]
# # UNDERSTANDING DATA

# %%
df.head()
# Out:
#    Price  Age_08_04     KM Fuel_Type  HP  Automatic    cc  Doors  Cylinders  \
# 0  13500         23  46986    Diesel  90          0  2000      3          4
# 1  13750         23  72937    Diesel  90          0  2000      3          4
# 2  13950         24  41711    Diesel  90          0  2000      3          4
# 3  14950         26  48000    Diesel  90          0  2000      3          4
# 4  13750         30  38500    Diesel  90          0  2000      3          4
#
#    Gears  Weight
# 0      5    1165
# 1      5    1165
# 2      5    1165
# 3      5    1165
# 4      5    1170

# %%
df['Fuel_Type'].value_counts()
# Out:
# Fuel_Type
# Petrol    1264
# Diesel     155
# CNG         17
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age_08_04  1436 non-null   int64
#  2   KM         1436 non-null   int64
#  3   Fuel_Type  1436 non-null   object
#  4   HP         1436 non-null   int64
#  5   Automatic  1436 non-null   int64
#  6   cc         1436 non-null   int64
#  7   Doors      1436 non-null   int64
#  8   Cylinders  1436 non-null   int64
#  9   Gears      1436 non-null   int64
#  10  Weight     1436 non-null   int64
# dtypes: int64(10), object(1)
# memory usage: 123.5+ KB

# %%
df.shape
# Out:
# (1436, 11)

# %%
df.isnull().sum()
# Out:
# Price        0
# Age_08_04    0
# KM           0
# Fuel_Type    0
# HP           0
# Automatic    0
# cc           0
# Doors        0
# Cylinders    0
# Gears        0
# Weight       0
# dtype: int64

# %%
df.describe()
# Out:
#               Price    Age_08_04             KM           HP    Automatic  \
# count   1436.000000  1436.000000    1436.000000  1436.000000  1436.000000
# mean   10730.824513    55.947075   68533.259749   101.502089     0.055710
# std     3626.964585    18.599988   37506.448872    14.981080     0.229441
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    44.000000   43000.000000    90.000000     0.000000
# 50%     9900.000000    61.000000   63389.500000   110.000000     0.000000
# 75%    11950.000000    70.000000   87020.750000   110.000000     0.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#                 cc        Doors  Cylinders        Gears      Weight
# count   1436.00000  1436.000000     1436.0  1436.000000  1436.00000
# mean    1576.85585     4.033426        4.0     5.026462  1072.45961
# std      424.38677     0.952677        0.0     0.188510    52.64112
# ...

# %% [markdown]
# # CHECKING DATA DISTRIBUTION THROUGH VISUALIZATION

# %%
df.hist(bins=20, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# # OUTLIERS DETECTION

# %%
There is no need to remove or imputate outliers because toyato coralla cars max weight is 1650 kg and km can be infinite as per maintainance

# %%
plt.boxplot(df['KM'])
df['Weight'].describe()
# Out:
# count    1436.00000
# mean     1072.45961
# std        52.64112
# min      1000.00000
# 25%      1040.00000
# 50%      1070.00000
# 75%      1085.00000
# max      1615.00000
# Name: Weight, dtype: float64

# %%
plt.boxplot(df['Weight'])
df['Weight'].describe()
# Out:
# count    1436.00000
# mean     1072.45961
# std        52.64112
# min      1000.00000
# 25%      1040.00000
# 50%      1070.00000
# 75%      1085.00000
# max      1615.00000
# Name: Weight, dtype: float64

# %%
df = pd.get_dummies(df).astype(int)

# %%
df
# Out:
#       Price  Age_08_04     KM   HP  Automatic    cc  Doors  Cylinders  Gears  \
# 0     13500         23  46986   90          0  2000      3          4      5
# 1     13750         23  72937   90          0  2000      3          4      5
# 2     13950         24  41711   90          0  2000      3          4      5
# 3     14950         26  48000   90          0  2000      3          4      5
# 4     13750         30  38500   90          0  2000      3          4      5
# ...     ...        ...    ...  ...        ...   ...    ...        ...    ...
# 1431   7500         69  20544   86          0  1300      3          4      5
# 1432  10845         72  19000   86          0  1300      3          4      5
# 1433   8500         71  17016   86          0  1300      3          4      5
# 1434   7250         70  16916   86          0  1300      3          4      5
# 1435   6950         76      1  110          0  1600      5          4      5
#
# ...

# %% [markdown]
# # CHECKING LINEARITY

# %%
sns.pairplot(kind = 'scatter', data = df)

# %% [markdown]
# # CORRELATION MATRIX

# %%
df.corr()
# Out:
#                      Price  Age_08_04        KM        HP  Automatic  \
# Price             1.000000  -0.876590 -0.569960  0.314990   0.033081
# Age_08_04        -0.876590   1.000000  0.505672 -0.156622   0.031717
# KM               -0.569960   0.505672  1.000000 -0.333538  -0.081854
# HP                0.314990  -0.156622 -0.333538  1.000000   0.013144
# Automatic         0.033081   0.031717 -0.081854  0.013144   1.000000
# cc                0.126389  -0.098084  0.102683  0.035856   0.066740
# Doors             0.185326  -0.148359 -0.036197  0.092424  -0.027654
# Cylinders              NaN        NaN       NaN       NaN        NaN
# Gears             0.063104  -0.005364  0.015023  0.209477  -0.098555
# Weight            0.581198  -0.470253 -0.028598  0.089614   0.057249
# Fuel_Type_CNG    -0.039536   0.002389  0.144016  0.062109   0.001486
# Fuel_Type_Diesel  0.054084  -0.097740  0.403060 -0.533453  -0.084490
# Fuel_Type_Petrol -0.038516   0.092611 -0.433160  0.489110   0.080249
#
# ...

# %%
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
print(df['Age_08_04'].corr(df['Price']), "\n", df['Weight'].corr(df['Price']), "\n", df['cc'].corr(df['Price']), "\n", df['KM'].corr(df['Price']))
# Out:
# -0.876590497143639
#  0.5811975886422478
#  0.12638919737589377
#  -0.5699601645337193

# %% [markdown]
# # MODEL BUILDING

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score

# %%
x = df[['Weight', 'KM', 'Age_08_04']]
y = df['Price']

# %%
#SPLITTING DATA
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, random_state = 1)

# %%
#FITTING REGRESSION MODEL
regressor = LinearRegression()
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#GETTING COEFFICIENT(C) AND INTERCEPT VALUES(M) (Y = MX + C)
print('coefficients: ', regressor.coef_)
print('intercept: ', regressor.intercept_)
# Out:
# coefficients:  [ 1.86457196e+01 -2.45641949e-02 -1.20382423e+02]
# intercept:  -864.1472978223974

# %%
#PREDICTION OF TEST RESULT
y_pred = regressor.predict(x_test)
print('predictions:\n', y_pred)
# Out:
# predictions:
#  [12043.62676334 10839.51011001 13955.31526688  7106.98240751
#  12517.30930533 18113.91416155  8016.7523654   9921.92622349
#   8322.13157435 13005.53737714  9766.88381462  9413.37885805
#   7523.43808375  8645.4821909   6825.09132183  8573.35101758
#   5801.50588532  8419.33121936 17354.00112601  5380.11285033
#  16631.70658958  7136.25627562  9430.83796367  5877.54771354
#  13129.60459531 19300.65363268  8155.75970345 10640.90303068
#  17636.4906429  11798.54436861  7493.20055593  8611.10880842
#  13444.21310342 17155.18153619 26213.14172663 10249.75502138
#  10951.16668037  7849.42410231  9513.9283388  16870.09696778
#  12094.21201185  8765.86160955  8253.60520775 10969.24056374
#   8027.55062243  9821.18720472 10816.88279385  8423.17109283
#   6719.59480123  7038.7319476   8735.98243415 12424.45795221
#   9186.89191097  7011.1731435   9114.37592572 18987.95519685
#  14546.97315519 11048.14993639 10117.76760167  6397.67428527
# ...

# %%
#COMPARING TEST AND PREDICTED VALUES
comparison_df = pd.DataFrame({"Actual":y_test, "predicted":y_pred})
print('Actual test data vs predicted: \n', comparison_df)
# Out:
# Actual test data vs predicted:
#        Actual     predicted
# 509    10900  12043.626763
# 435    10895  10839.510110
# 321    10750  13955.315267
# 1055    6500   7106.982408
# 288    11895  12517.309305
# ...      ...           ...
# 1359    8750   8278.569219
# 215    10950  13308.053204
# 135    16500  16861.934958
# 800     8995   8832.057641
# 994     7750   9300.522658
#
# [288 rows x 2 columns]

# %%
#GETTING PARAMETERS
print(mean_squared_error(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
print(r2_score(y_test, y_pred))
# Out:
# 1675756.233741678
# 973.0243658849608
# 0.881039717891467

# %% [markdown]
# # RIDGE REGRESSION MODEL

# %%
from sklearn.linear_model import Ridge 

ridgeR = Ridge(alpha = 500) 
ridgeR.fit(x_train, y_train) 
y_pred1 = ridgeR.predict(x_test) 

# PARAMS
mean_squared_error_ridge = np.mean((y_pred1 - y_test)**2) 
print(mean_squared_error_ridge) 
ridge_coefficient = pd.DataFrame() 
ridge_coefficient["Columns"]= x_train.columns 
ridge_coefficient['Coefficient Estimate'] = pd.Series(ridgeR.coef_) 
print(ridge_coefficient) 
comparison_df = pd.DataFrame({"Actual":y_test, "predicted":y_pred1})
print('Actual test data vs predicted: \n', comparison_df)
# Out:
# 1675782.3881878573
#      Columns  Coefficient Estimate
# 0     Weight             18.686462
# 1         KM             -0.024631
# 2  Age_08_04           -120.106627
# Actual test data vs predicted:
#        Actual     predicted
# 509    10900  12041.353170
# 435    10895  10838.024291
# 321    10750  13952.066219
# 1055    6500   7105.161978
# 288    11895  12515.121313
# ...      ...           ...
# 1359    8750   8286.313153
# 215    10950  13301.218068
# 135    16500  16855.991073
# 800     8995   8833.808464
# 994     7750   9302.099024
#
# [288 rows x 2 columns]

# %% [markdown]
# # LASSO REGRESSION MODEL

# %%
from sklearn.linear_model import Lasso 

lasso = Lasso(alpha = 1) 
lasso.fit(x_train, y_train) 
y_pred2 = lasso.predict(x_test) 

#PARAMS 
mean_squared_error = np.mean((y_pred2 - y_test)**2) 
print("Mean squared error on test set", mean_squared_error) 
lasso_coeff = pd.DataFrame() 
lasso_coeff["Columns"] = x_train.columns 
lasso_coeff['Coefficient Estimate'] = pd.Series(lasso.coef_) 
print(lasso_coeff) 
comparison_df = pd.DataFrame({"Actual":y_test, "predicted":y_pred2})
print('Actual test data vs predicted: \n', comparison_df)
# Out:
# Mean squared error on test set 1675764.2678741084
#      Columns  Coefficient Estimate
# 0     Weight             18.646079
# 1         KM             -0.024565
# 2  Age_08_04           -120.377872
# Actual test data vs predicted:
#        Actual     predicted
# 509    10900  12043.593135
# 435    10895  10839.484460
# 321    10750  13955.261075
# 1055    6500   7106.937476
# 288    11895  12517.277210
# ...      ...           ...
# 1359    8750   8278.692992
# 215    10950  13307.939322
# 135    16500  16861.825467
# 800     8995   8832.093285
# 994     7750   9300.566758
#
# [288 rows x 2 columns]

# %% [markdown]
# 1)What is Normalization & Standardization and how is it helpful?
#
#
# A)Normalization is used to fit data points btween -1 to 1 from better data distribution
#   Standardization is used to fit data points between mean(0) and standard deviation(1) for understanding of data points
#   it is helpful when we handel large data points such as 2013, 2150 and etc., it is also knowwn as MIN-MAX scaling

# %% [markdown]
# 2)What techniques can be used to address multicollinearity in multiple linear regression?
#
#
# A)pearson correlation technique is used to find the multicollinearity between independent feature,
# if there is any multicollinearity between independent features then its hard to estimate relationship between dependent and independent features
